# %%
import re 
import pdfplumber

import csv

DATE_STRING = '2020-05-12'

outfile = 'covid_conjugate_0512.csv'
outfileh = open(outfile, 'w')
writer = csv.writer(outfileh)

writer.writerow(['facility','county', 'first_reported', 'cases', 'deaths', 'report_date'])

file = "../or_weekly_reports/COVID-19-Weekly-Report-%s-FINAL.pdf" % DATE_STRING
pdf = pdfplumber.open(file)

# %%
settings = {
    "vertical_strategy": "lines", 
    "horizontal_strategy": "words",
    "snap_tolerance": 3,
    "join_tolerance": 3,
    "edge_min_length": 3,
    "min_words_vertical": 3,
    "min_words_horizontal": 1,
    "keep_blank_chars": False,
    "text_tolerance": 3,
    "text_x_tolerance": None,
    "text_y_tolerance": None,
    "intersection_tolerance": 3,
    "intersection_x_tolerance": None,
    "intersection_y_tolerance": None,
}

# %%
pagenumber = 7

# %%
#im = pdf.pages[pagenumber].to_image()
width = pdf.pages[pagenumber].width
height = pdf.pages[pagenumber].height
box1 = (0, 150,  width, height)

cropped_page = pdf.pages[pagenumber].crop(box1) 
im = cropped_page.to_image()
im.debug_tablefinder()

## Note that there is no "start_date" for this report

# %%
table_found = cropped_page.extract_table(table_settings={})
result_count = len(table_found)
# Skip the header row
for i in range(1,result_count):
    this_row = table_found[i]

    if not this_row[0]:
        # hack for misread 
        print("Empty-ish row, continuing")
        continue
    if this_row[0]=='Total':
        continue
    print(len(this_row))
    assert len(this_row)==5
    print(this_row)
    this_row.append(DATE_STRING)
    writer.writerow(this_row)
# Out:
# 5
# ["Oregon Veterans' Home Lebanon", 'Linn', '3/11/2020', '38', '7']
# 5
# ['The Oaks at Sherwood Park', 'Marion', '3/20/2020', '14', '1']
# 5
# ['Regency Park', 'Washington', '3/21/2020', '16', '1']
# 5
# ['Astor House Senior Living', 'Yamhill', '3/22/2020', '15', '7']
# 5
# ['Healthcare at Foster Creek', 'Multnomah', '3/24/2020', '119', '29']
# 5
# ["Oregon Veterans' Home The Dalles", 'Wasco', '3/26/2020', '3', '0']
# 5
# ['Raleigh Hills Senior Care', 'Washington', '3/27/2020', '1', '1']
# 5
# ['Corvallis Manor', 'Benton', '3/27/2020', '17', '3']
# 5
# ['Salem Transitional Care', 'Marion', '3/27/2020', '26', '3']
# 5
# ['Shelter at Orenco Station', 'Washington', '3/30/2020', '4', '0']
# 5
# ['Laurelhurst Village', 'Multnomah', '3/30/2020', '48', '4']
# 5
# ['Marquis Marian Estates', 'Marion', '3/30/2020', '16', '1']
# 5
# ['Avamere at Bethany', 'Washington', '4/1/2020', '9', '0']
# 5
# ['Village Health Care', 'Multnomah', '4/1/2020', '37', '5']
# 5
# ['Bonaventure', 'Washington', '4/1/2020', '1', '1']
# 5
# ['Four Seasons Memory Care', 'Marion', '4/2/2020', '4', '1']
# 5
# ['Jason Lee Manor Apartments', 'Marion', '4/10/2020', '2', '1']
# 5
# ['Avamere Court at Keizer', 'Marion', '4/11/2020', '3', '1']
# 5
# ['Powell Valley Memory Care', 'Multnomah', '4/13/2020', '9', '1']
# 5
# ['Country Meadows Village', 'Marion', '4/13/2020', '6', '1']
# 5
# ['Cornerstone Care Options', 'Multnomah', '4/16/2020', '16', '0']
# 5
# ['The Grove Assisted Living', 'Washington', '4/17/2020', '3', '1']
# 5
# ['Countryside Living of Canby', 'Clackamas', '4/19/2020', '12', '2']
# 5
# ['St. Andrews Memory Care', 'Multnomah', '4/21/2020', '3', '0']
# 5
# ['Cherrywood Village', 'Multnomah', '4/23/2020', '6', '1']
# 5
# ['Turner Residential Care', 'Marion', '4/23/2020', '1', '1']
# 5
# ['Prestige Senior Living Orchard \nHeights', 'Polk', '4/30/2020', '41', '4']

# %%
## that's the end! In other reports there might be more.

# %%
outfileh.close()
